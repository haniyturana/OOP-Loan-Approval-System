# %%
# credit_test_notebook.ipynb
import importlib
import step2_Pt2_module
importlib.reload(step2_Pt2_module) #need to add function .relod because sometime, the changes at the module not get reflected

from step2_Pt2_module import * # to import all define functions at step2_Pt2_module

# Create 5 Parent class instances
customers = [
    Customer("Ali", 35, 5000, 1000), #Instance1
    Customer("Siti", 28, 8000, 2500),#Instance2
    Customer("John", 45, 10000, 4000),#Instance3
    Customer("Mary", 30, 6000, 1200),#Instance4
    Customer("David", 50, 9000, 2000)#Instance5
]
for cust in customers:
    print_customer_risk(cust)
    print("-"*30)

# Create 5 Child class instances
credit_customers = [
    CreditScoreCustomer("Ali", 35, 5000, 1000, 720),#Instance1
    CreditScoreCustomer("Siti", 28, 8000, 2500, 680),#Instance2
    CreditScoreCustomer("John", 45, 10000, 4000, 600),#Instance3
    CreditScoreCustomer("Mary", 30, 6000, 1200, 770),#Instance4
    CreditScoreCustomer("David", 50, 9000, 2000, 540)#Instance5
]
for ccust in credit_customers:
    print_customer_risk(ccust)
    print("-"*30)
# Out:
# Name: Ali
# Age: 35
# Income (RM): 5,000
# Monthly Debt (RM): 1,000
# DTI: 20%
# DTI Risk Category: Medium Risk
# ----------------------------------------
# ------------------------------
# Name: Siti
# Age: 28
# Income (RM): 8,000
# Monthly Debt (RM): 2,500
# DTI: 31%
# DTI Risk Category: Medium Risk
# ----------------------------------------
# ------------------------------
# Name: John
# Age: 45
# Income (RM): 10,000
# Monthly Debt (RM): 4,000
# DTI: 40%
# DTI Risk Category: High Risk
# ----------------------------------------
# ------------------------------
# Name: Mary
# Age: 30
# Income (RM): 6,000
# Monthly Debt (RM): 1,200
# DTI: 20%
# DTI Risk Category: Medium Risk
# ----------------------------------------
# ------------------------------
# Name: David
# Age: 50
# Income (RM): 9,000
# Monthly Debt (RM): 2,000
# DTI: 22%
# DTI Risk Category: Medium Risk
# ----------------------------------------
# ------------------------------
# Name: Ali
# Age: 35
# Income (RM): 5,000
# ...
